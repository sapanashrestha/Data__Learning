# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=c8345283069dc12c3e8639a11eace417')

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/yF1eOkaYvwiORauRCPWznV9xVvi.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 298618,
#    'original_language': 'en',
#    'original_title': 'The Flash',
#    'overview': "When his attempt to save his family inadvertently alters the future, Barry Allen becomes trapped in a reality in which General Zod has returned and there are no Super Heroes to turn to. In order to save the world that he is in and return to the future that he knows, Barry's only hope is to race for his life. But will making the ultimate sacrifice be enough to reset the universe?",
#    'popularity': 4631.142,
#    'poster_path': '/rktDFPbfHfUbArZ6OOOKsXcv0Bm.jpg',
#    'release_date': '2023-06-13',
#    'title': 'The Flash',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 1773},
#   {'adult': False,
#    'backdrop_path': '/nHf61UzkfFno5X1ofIhugCPus2R.jpg',
#    'genre_ids': [35, 12, 14],
#    'id': 346698,
# ...

# %%
pd.DataFrame(response.json())
# Out:
#     page                                            results  total_pages
# 0      1  {'adult': False, 'backdrop_path': '/yF1eOkaYvw...        39316  \
# 1      1  {'adult': False, 'backdrop_path': '/nHf61UzkfF...        39316
# 2      1  {'adult': False, 'backdrop_path': '/znUYFf0Sez...        39316
# 3      1  {'adult': False, 'backdrop_path': '/2vFuG6bWGy...        39316
# 4      1  {'adult': False, 'backdrop_path': '/f7UI3dYpr7...        39316
# 5      1  {'adult': False, 'backdrop_path': '/kCONdNN8JJ...        39316
# 6      1  {'adult': False, 'backdrop_path': '/5YZbUmjbMa...        39316
# 7      1  {'adult': False, 'backdrop_path': '/J0XkW5toJL...        39316
# 8      1  {'adult': False, 'backdrop_path': '/14GEZCzCGh...        39316
# 9      1  {'adult': False, 'backdrop_path': '/4XM8DUTQb3...        39316
# 10     1  {'adult': False, 'backdrop_path': '/oqP1qEZccq...        39316
# 11     1  {'adult': False, 'backdrop_path': '/fm6KqXpk3M...        39316
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path                   genre_ids
# 0   False  /yF1eOkaYvwiORauRCPWznV9xVvi.jpg               [28, 12, 878]  \
# 1   False  /nHf61UzkfFno5X1ofIhugCPus2R.jpg                [35, 12, 14]
# 2   False  /znUYFf0Sez5lUmxPr3Cby7TVJ6c.jpg      [12, 10751, 14, 10749]
# 3   False  /2vFuG6bWGyQUzYS9d69E5l85nIz.jpg               [28, 12, 878]
# 4   False  /f7UI3dYpr7ZUHGo0iIr1Qvy1VPe.jpg         [16, 10751, 14, 35]
# 5   False  /kCONdNN8JJFM6GAnzc03pBFjRFH.jpg                [16, 28, 27]
# 6   False  /5YZbUmjbMa3ClvSW1Wj3D6XGolb.jpg               [878, 12, 28]
# 7   False   /J0XkW5toJLGEucm1pLDvTHXaKC.jpg             [28, 18, 10752]
# 8   False  /14GEZCzCGhV7FMFaWi4Ec22Kcai.jpg         [16, 12, 10751, 14]
# 9   False  /4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg                [28, 80, 53]
# 10  False  /oqP1qEZccq5AD9TVTIaO6IGUj7o.jpg                [14, 28, 12]
# 11  False  /fm6KqXpk3M2HVveHwCrBSSBaO0V.jpg                    [18, 36]
# ...

# %%
df=pd.DataFrame(response.json()['results'])[['title','release_date','vote_average','vote_count']]

# %%
df
# Out:
#                                   title release_date  vote_average  vote_count
# 0                             The Flash   2023-06-13           6.9        1773
# 1                                Barbie   2023-07-19           7.6        1621
# 2                    The Little Mermaid   2023-05-18           6.4        1182
# 3      Transformers: Rise of the Beasts   2023-06-06           7.5        2065
# 4          Ruby Gillman, Teenage Kraken   2023-06-28           7.8         308
# 5           Resident Evil: Death Island   2023-06-22           7.9         236
# 6        Guardians of the Galaxy Vol. 3   2023-05-03           8.1        3583
# 7                          Warhorse One   2023-06-30           7.2          82
# 8                Mavka: The Forest Song   2023-03-02           7.5         169
# 9                                Fast X   2023-05-17           7.3        3008
# 10                Knights of the Zodiac   2023-04-27           6.6         656
# ...

# %%
df.sort_values('vote_average',ascending=False)
# Out:
#                                   title release_date  vote_average  vote_count
# 15  Spider-Man: Across the Spider-Verse   2023-05-31           8.5        2541
# 11                          Oppenheimer   2023-07-19           8.4         999
# 6        Guardians of the Galaxy Vol. 3   2023-05-03           8.1        3583
# 13                     Sound of Freedom   2023-07-03           8.0         240
# 5           Resident Evil: Death Island   2023-06-22           7.9         236
# 17                 John Wick: Chapter 4   2023-03-22           7.8        3960
# 4          Ruby Gillman, Teenage Kraken   2023-06-28           7.8         308
# 14          The Super Mario Bros. Movie   2023-04-05           7.8        5941
# 1                                Barbie   2023-07-19           7.6        1621
# 12                            Elemental   2023-06-14           7.6         650
# 3      Transformers: Rise of the Beasts   2023-06-06           7.5        2065
# ...

# %%
df.sort_values('vote_count',ascending=False)
# Out:
#                                   title release_date  vote_average  vote_count
# 14          The Super Mario Bros. Movie   2023-04-05           7.8        5941
# 17                 John Wick: Chapter 4   2023-03-22           7.8        3960
# 6        Guardians of the Galaxy Vol. 3   2023-05-03           8.1        3583
# 9                                Fast X   2023-05-17           7.3        3008
# 15  Spider-Man: Across the Spider-Verse   2023-05-31           8.5        2541
# 3      Transformers: Rise of the Beasts   2023-06-06           7.5        2065
# 0                             The Flash   2023-06-13           6.9        1773
# 1                                Barbie   2023-07-19           7.6        1621
# 2                    The Little Mermaid   2023-05-18           6.4        1182
# 11                          Oppenheimer   2023-07-19           8.4         999
# 10                Knights of the Zodiac   2023-04-27           6.6         656
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(50, 25))  # Set the size of the figure (width, height)
plt.bar(df['title'], df['vote_count'], color='skyblue')
plt.xlabel('Movie Title')
plt.ylabel('Vote Count')
plt.title('Movie Vote Count Bar Graph')
# Out:
# Text(0.5, 1.0, 'Movie Vote Count Bar Graph')
